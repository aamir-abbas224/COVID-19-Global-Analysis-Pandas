# %%
import pandas as pd
import glob

df = glob.glob(r'C:\Users\Aamir Bin Abbas\Desktop\Projects and thesis\Pandas\COVID-19 Global Data\archive\*.csv')

df_list = [pd.read_csv(file) for file in df]
df = pd.concat(df_list, ignore_index=True)

df.head(5)
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan    36263.0  1269.0    25198.0  9796.0      106.0        10.0
# 1        Albania     4880.0   144.0     2745.0  1991.0      117.0         6.0
# 2        Algeria    27973.0  1163.0    18837.0  7973.0      616.0         8.0
# 3        Andorra      907.0    52.0      803.0    52.0       10.0         0.0
# 4         Angola      950.0    41.0      242.0   667.0       18.0         1.0
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  ...  TotalDeaths  \
# 0           18.0                3.50                  69.49  ...          NaN
# 1           63.0                2.95                  56.25  ...          NaN
# 2          749.0                4.16                  67.34  ...          NaN
# 3            0.0                5.73                  88.53  ...          NaN
# 4            0.0                4.32                  25.47  ...          NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 712728 entries, 0 to 712727
# Data columns (total 44 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Country/Region          84620 non-null   object
#  1   Confirmed               712519 non-null  float64
#  2   Deaths                  712519 non-null  float64
#  3   Recovered               84599 non-null   float64
#  4   Active                  84599 non-null   float64
#  5   New cases               35531 non-null   float64
#  6   New deaths              35531 non-null   float64
#  7   New recovered           35531 non-null   float64
#  8   Deaths / 100 Cases      375 non-null     float64
#  9   Recovered / 100 Cases   375 non-null     float64
#  10  Deaths / 100 Recovered  375 non-null     float64
#  11  Confirmed last week     187 non-null     float64
#  12  1 week change           187 non-null     float64
# ...

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# %%
df
# Out:
#                country/region  confirmed  deaths  recovered  active  \
# 0                 Afghanistan    36263.0  1269.0    25198.0  9796.0
# 1                     Albania     4880.0   144.0     2745.0  1991.0
# 2                     Algeria    27973.0  1163.0    18837.0  7973.0
# 3                     Andorra      907.0    52.0      803.0    52.0
# 4                      Angola      950.0    41.0      242.0   667.0
# ...                       ...        ...     ...        ...     ...
# 712723             Montserrat        NaN     NaN        NaN     NaN
# 712724  Caribbean Netherlands        NaN     NaN        NaN     NaN
# 712725       Falkland Islands        NaN     NaN        NaN     NaN
# 712726           Vatican City        NaN     NaN        NaN     NaN
# 712727         Western Sahara        NaN     NaN        NaN     NaN
#
#         new_cases  new_deaths  new_recovered  deaths_/_100_cases  \
# 0           106.0        10.0           18.0                3.50
# ...

# %%
df['date'] = pd.to_datetime(df['date'], errors='coerce')
# Out:
# C:\Users\Aamir Bin Abbas\AppData\Local\Temp\ipykernel_25348\2370506791.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = pd.to_datetime(df['date'], errors='coerce')

# %%
df
# Out:
#                country/region  confirmed  deaths  recovered  active  \
# 0                 Afghanistan    36263.0  1269.0    25198.0  9796.0
# 1                     Albania     4880.0   144.0     2745.0  1991.0
# 2                     Algeria    27973.0  1163.0    18837.0  7973.0
# 3                     Andorra      907.0    52.0      803.0    52.0
# 4                      Angola      950.0    41.0      242.0   667.0
# ...                       ...        ...     ...        ...     ...
# 712723             Montserrat        NaN     NaN        NaN     NaN
# 712724  Caribbean Netherlands        NaN     NaN        NaN     NaN
# 712725       Falkland Islands        NaN     NaN        NaN     NaN
# 712726           Vatican City        NaN     NaN        NaN     NaN
# 712727         Western Sahara        NaN     NaN        NaN     NaN
#
#         new_cases  new_deaths  new_recovered  deaths_/_100_cases  \
# 0           106.0        10.0           18.0                3.50
# ...

# %%
df['province_state'].fillna('Unknown', inplace=True)
df['country_region'].fillna('Unknown', inplace=True)
df['who_region'].fillna('Unknown', inplace=True)
# Out:
# C:\Users\Aamir Bin Abbas\AppData\Local\Temp\ipykernel_25348\479971105.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['province_state'].fillna('Unknown', inplace=True)
# C:\Users\Aamir Bin Abbas\AppData\Local\Temp\ipykernel_25348\479971105.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df['confirmed'].fillna(0, inplace=True)
df['deaths'].fillna(0, inplace=True)
df['recovered'].fillna(0, inplace=True)
# Out:
# C:\Users\Aamir Bin Abbas\AppData\Local\Temp\ipykernel_25348\652577326.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['confirmed'].fillna(0, inplace=True)
# C:\Users\Aamir Bin Abbas\AppData\Local\Temp\ipykernel_25348\652577326.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df['active'] = df['confirmed'] - df['deaths'] - df['recovered']

# %%
df.drop_duplicates(inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                country/region  confirmed  deaths  recovered  active  \
# 0                 Afghanistan    36263.0  1269.0    25198.0  9796.0
# 1                     Albania     4880.0   144.0     2745.0  1991.0
# 2                     Algeria    27973.0  1163.0    18837.0  7973.0
# 3                     Andorra      907.0    52.0      803.0    52.0
# 4                      Angola      950.0    41.0      242.0   667.0
# ...                       ...        ...     ...        ...     ...
# 288620             Montserrat        0.0     0.0        0.0     0.0
# 288621  Caribbean Netherlands        0.0     0.0        0.0     0.0
# 288622       Falkland Islands        0.0     0.0        0.0     0.0
# 288623           Vatican City        0.0     0.0        0.0     0.0
# 288624         Western Sahara        0.0     0.0        0.0     0.0
#
#         new_cases  new_deaths  new_recovered  deaths_/_100_cases  \
# 0           106.0        10.0           18.0                3.50
# ...

# %%
df.groupby('country/region')['confirmed'].sum().sort_values(ascending=False).head(10)
# Out:
# country/region
# US                452982155.0
# Brazil            181492309.0
# Russia             91633502.0
# India              83247001.0
# Spain              55080511.0
# United Kingdom     53798882.0
# Italy              53736576.0
# France             42642204.0
# Germany            42325416.0
# Iran               38972140.0
# Name: confirmed, dtype: float64

# %%
df.groupby('country/region')['deaths'].sum().sort_values(ascending=False).head(10)
# Out:
# country/region
# US                22170833.0
# United Kingdom     8041394.0
# Brazil             7963686.0
# Italy              7450546.0
# France             6127260.0
# Spain              6094492.0
# Mexico             3500576.0
# India              2257070.0
# Iran               2064184.0
# Belgium            1937180.0
# Name: deaths, dtype: float64

# %%
df.groupby('country/region')['active'].sum().sort_values(ascending=False).head(10)
# Out:
# country/region
# US                316778686.0
# Brazil             62696236.0
# United Kingdom     45503617.0
# Russia             39538253.0
# India              32471325.0
# France             22069502.0
# Spain              18648477.0
# Canada             17421484.0
# Peru               15596666.0
# Italy              14739617.0
# Name: active, dtype: float64

# %%
df.groupby('date')['confirmed'].sum().plot(title='Global Confirmed Cases Over Time')
# Out:
# <Axes: title={'center': 'Global Confirmed Cases Over Time'}, xlabel='date'>

# %%
df = df[['date','country/region','province/state','confirmed','deaths','recovered','active','new_cases','new_deaths','new_recovered']]

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#        date         country/region province/state  confirmed  deaths  \
# 0       NaT            Afghanistan            NaN    36263.0  1269.0
# 1       NaT                Albania            NaN     4880.0   144.0
# 2       NaT                Algeria            NaN    27973.0  1163.0
# 3       NaT                Andorra            NaN      907.0    52.0
# 4       NaT                 Angola            NaN      950.0    41.0
# ...     ...                    ...            ...        ...     ...
# 288620  NaT             Montserrat            NaN        0.0     0.0
# 288621  NaT  Caribbean Netherlands            NaN        0.0     0.0
# 288622  NaT       Falkland Islands            NaN        0.0     0.0
# 288623  NaT           Vatican City            NaN        0.0     0.0
# 288624  NaT         Western Sahara            NaN        0.0     0.0
#
#         recovered  active  new_cases  new_deaths  new_recovered
# 0         25198.0  9796.0      106.0        10.0           18.0
# ...

# %%
df.columns
# Out:
# Index(['date', 'country/region', 'province/state', 'confirmed', 'deaths',
#        'recovered', 'active', 'new_cases', 'new_deaths', 'new_recovered'],
#       dtype='object')

# %%
df['province/state'].fillna('Unknown', inplace=True)
df['country/region'].fillna('Unknown', inplace=True)

df['confirmed'].fillna(0, inplace=True)
df['deaths'].fillna(0, inplace=True)
df['recovered'].fillna(0, inplace=True)
df['active'].fillna(df['confirmed'] - df['deaths'] - df['recovered'], inplace=True)
# Out:
# C:\Users\Aamir Bin Abbas\AppData\Local\Temp\ipykernel_25348\3316157153.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['province/state'].fillna('Unknown', inplace=True)
# C:\Users\Aamir Bin Abbas\AppData\Local\Temp\ipykernel_25348\3316157153.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.groupby('country/region')['confirmed'].sum().sort_values(ascending=False).head(10)
# Out:
# country/region
# Unknown           1.040567e+09
# US                4.529822e+08
# Brazil            1.814923e+08
# Russia            9.163350e+07
# India             8.324700e+07
# Spain             5.508051e+07
# United Kingdom    5.379888e+07
# Italy             5.373658e+07
# France            4.264220e+07
# Germany           4.232542e+07
# Name: confirmed, dtype: float64

# %%
df.groupby('date')['confirmed'].sum().plot(title='Global Confirmed Cases')
# Out:
# <Axes: title={'center': 'Global Confirmed Cases'}, xlabel='date'>

# %%
df
# Out:
#        date         country/region province/state  confirmed  deaths  \
# 0       NaT            Afghanistan        Unknown    36263.0  1269.0
# 1       NaT                Albania        Unknown     4880.0   144.0
# 2       NaT                Algeria        Unknown    27973.0  1163.0
# 3       NaT                Andorra        Unknown      907.0    52.0
# 4       NaT                 Angola        Unknown      950.0    41.0
# ...     ...                    ...            ...        ...     ...
# 288620  NaT             Montserrat        Unknown        0.0     0.0
# 288621  NaT  Caribbean Netherlands        Unknown        0.0     0.0
# 288622  NaT       Falkland Islands        Unknown        0.0     0.0
# 288623  NaT           Vatican City        Unknown        0.0     0.0
# 288624  NaT         Western Sahara        Unknown        0.0     0.0
#
#         recovered  active  new_cases  new_deaths  new_recovered
# 0         25198.0  9796.0      106.0        10.0           18.0
# ...

# %%
df.to_csv('Covid 19 Combined Cleaned Data')
